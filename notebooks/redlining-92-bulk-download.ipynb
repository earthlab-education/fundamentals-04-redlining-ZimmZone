# %% [markdown]
# # Bulk Download Data with `earthaccess`
#
# Whew – we’ve processed some reflectance data! But you may have noticed
# that your image doesn’t include all of Denver, or all the spectral bands
# you will need – Your search returned 60 different files covering
# different spectral bands and spatial areas! To work with all of them, we
# will have to utilize **DRY** coding techniques – `for` loops and
# functions.
#
# First things first – load your stored variables into memory:

# %%
# %store -r denver_redlining_gdf project_dir

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Import packages</div></div><div class="callout-body-container callout-body"><p>Add imports for packages that help you:</p>
# <ol type="1">
# <li>Work with the file system interoperably</li>
# <li>Work with vector data</li>
# <li>Create interactive plots of vector data</li>
# <li>Group and aggregate tabular data</li>
# </ol></div></div>

# %%
# Interoperable file paths
import re # Use regular expressions to extract metadata

import earthaccess # Access NASA data from the cloud
import matplotlib.pyplot as plt # Overlay plots
import numpy as np # Process bit-wise cloud mask
import pandas as pd # Group and aggregate
import rioxarray as rxr # Work with raster data
from rioxarray.merge import merge_arrays # Merge rasters

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Set up `earthaccess` connection</div></div><div class="callout-body-container callout-body"><p>As you did before, log in to your <code>earthaccess</code> account,
# search for the Denver data, and open the file connections. You will find
# that you have to re-run your search every time you access a file – keep
# this in mind if you get errors later!</p></div></div>

# %%
# Search earthaccess
earthaccess.login(strategy="interactive", persist=True)

# Search for HLS data
denver_results = earthaccess.search_data(
    short_name="HLSL30",
    bounding_box=tuple(denver_redlining_gdf.total_bounds),
    temporal=("2024-07-12", "2024-07-13"),
    count=1
)
denver_results

# Open the data connections
denver_files = earthaccess.open(denver_results)
# Out:
# QUEUEING TASKS | :   0%|          | 0/15 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/15 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ## Putting it all together
#
# To get a complete image, we will have to:
#
# 1.  Load in all 4 rasters that cover Denver
# 2.  Process them
# 3.  Merge, or mosaic, them into one image
#
# And…we haven’t even talked about the other bands you might need, or what
# to do if you want a time-series of images. You can see that if we were
# to copy and paste all the code above for each raster we need to load, it
# could get pretty overwhelming, and *very* error-prone. This is the
# opposite of what we mean by **DRY** (Don’t Repeat Yourself) code.
#
# Before we continue, we’re going to make some functions to do the tasks
# you completed up above. We’ve already set up the code for you,
# identified **parameters** and **returns**, and added **docstrings** to
# document your function. When writing a function, we recommend the
# following process:
#
# 1.  Copy the code you’re using into the function shell, making sure to
#     indent it so Python knows it is part of the function.
# 2.  Identify any variables that are **too specific**. For example, if I
#     called a `DataArray` `denver_da`, but I could use my function to
#     process data from anywhere…I might change the name to `da` whereever
#     it appears.
# 3.  Identify the function **parameters** or arguments and make sure they
#     match your code. Python may let you, but we recommend not using
#     variables defined outside the function inside the function – if you
#     need something in your function make sure to pass it in as a
#     parameter!
# 4.  Identify the function **returns** and make sure they match your
#     code. What do you want to be able to access at the end? Keep in mind
#     that unless you return them, the variables you create in a function
#     will be stuck there. The `return` statement at the end of your
#     function will pass the variables you want to keep back out of the
#     function.
# 5.  Write some code to test your function, such as by plotting the
#     results. We recommend going line by line when you’re just getting
#     started. This usually involves commenting code later on, and
#     modifying the returns and test code as you go.
# 6.  Restart the kernel and run your function to check that doesn’t have
#     any hidden requirements.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: DRY code with functions</div></div><div class="callout-body-container callout-body"><p>Take each processing step from above, and create a function to do it.
# We recommend writing the following 2 functions:</p>
# <ol type="1">
# <li>A function to load a raster, crop it, and apply the scale
# factor</li>
# <li>A function to process the cloud mask</li>
# </ol>
# <p>Applying the cloud mask is a single line of code, so we don’t think
# it needs its own function.</p>
# <p>Make sure to test all your functions using your example from up
# top!</p></div></div>

# %%
def process_image(uri, bounds_gdf):
    """
    Load, crop, and scale a raster image from earthaccess

    Parameters
    ----------
    uri: file-like or path-like
      File accessor downloaded or obtained from earthaccess
    bounds_gdf: gpd.GeoDataFrame
      Area of interest to crop to

    Returns
    -------
    cropped_da: rxr.DataArray
      Processed raster
    """
    # Connect to the raster image
    da = rxr.open_rasterio(uri, mask_and_scale=True).squeeze()

    # Get the total boundary
    bounds = (
      bounds_gdf
      .to_crs(da.rio.crs)
      .total_bounds
)

  # Crop
    cropped_da = da.rio.clip_box(*bounds)

    return cropped_da

process_image(denver_files[8], denver_redlining_gdf)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/implementations/http.py:668, in HTTPFile.async_fetch_range(self, start, end)
#     666 if response_is_range:
#     667     # partial content, as expected
# --> 668     out = await r.read()
#     669 elif start > 0:
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/aiohttp/client_reqrep.py:1111, in ClientResponse.read(self)
#    1110 try:
# -> 1111     self._body = await self.content.read()
#    1112     for trace in self._traces:
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/aiohttp/streams.py:383, in StreamReader.read(self, n)
#     382 while True:
# --> 383     block = await self.readany()
#     384     if not block:
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/aiohttp/streams.py:405, in StreamReader.readany(self)
#     404 while not self._buffer and not self._eof:
# --> 405     await self._wait("readany")
#     407 return self._read_nowait(-1)
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/aiohttp/streams.py:311, in StreamReader._wait(self, func_name)
#     310 try:
# --> 311     with self._timer:
#     312         await waiter
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/aiohttp/helpers.py:735, in TimerContext.__exit__(self, exc_type, exc_val, exc_tb)
#     734 if exc_type is asyncio.CancelledError and self._cancelled:
# --> 735     raise asyncio.TimeoutError from None
#     736 return None
#
# TimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# FSTimeoutError                            Traceback (most recent call last)
# Cell In[5], line 32
#      28     cropped_da = da.rio.clip_box(*bounds)
#      30     return cropped_da
# ---> 32 process_image(denver_files[8], denver_redlining_gdf)
#
# Cell In[5], line 18, in process_image(uri, bounds_gdf)
#       2     """
#       3     Load, crop, and scale a raster image from earthaccess
#       4
#    (...)
#      15       Processed raster
#      16     """
#      17     # Connect to the raster image
# ---> 18     da = rxr.open_rasterio(uri, mask_and_scale=True).squeeze()
#      20     # Get the total boundary
#      21     bounds = (
#      22       bounds_gdf
#      23       .to_crs(da.rio.crs)
#      24       .total_bounds
#      25 )
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/rioxarray/_io.py:1128, in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, band_as_variable, **open_kwargs)
#    1126     else:
#    1127         manager = URIManager(file_opener, filename, mode="r", kwargs=open_kwargs)
# -> 1128     riods = manager.acquire()
#    1129     captured_warnings = rio_warnings.copy()
#    1131 # raise the NotGeoreferencedWarning if applicable
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/rioxarray/_io.py:263, in URIManager.acquire(self, needs_lock)
#     259 if self._local.thread_manager is None:
#     260     self._local.thread_manager = ThreadURIManager(
#     261         self._opener, *self._args, mode=self._mode, kwargs=self._kwargs
#     262     )
# --> 263 return self._local.thread_manager.file_handle
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/rioxarray/_io.py:219, in ThreadURIManager.file_handle(self)
#     217 if self._file_handle is not None:
#     218     return self._file_handle
# --> 219 self._file_handle = self._opener(*self._args, mode=self._mode, **self._kwargs)
#     220 return self._file_handle
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/rasterio/__init__.py:297, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     290 # If the fp argument is a file-like object and can be adapted by
#     291 # rasterio's FilePath we do so. Otherwise, we use a MemoryFile to
#     292 # hold fp's contents and store that in an ExitStack attached to the
#     293 # dataset object that we will return. When a dataset's close method
#     294 # is called, this ExitStack will be unwound and the MemoryFile's
#     295 # storage will be cleaned up.
#     296 elif mode == 'r' and hasattr(fp, 'read'):
# --> 297     memfile = MemoryFile(fp.read())
#     298     fp.seek(0)
#     299     dataset = memfile.open(driver=driver, sharing=sharing, **kwargs)
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/spec.py:1939, in AbstractBufferedFile.read(self, length)
#    1936 if length == 0:
#    1937     # don't even bother calling fetch
#    1938     return b""
# -> 1939 out = self.cache._fetch(self.loc, self.loc + length)
#    1941 logger.debug(
#    1942     "%s read: %i - %i %s",
#    1943     self,
#    (...)
#    1946     self.cache._log_stats(),
#    1947 )
#    1948 self.loc += len(out)
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/caching.py:481, in BytesCache._fetch(self, start, end)
#     479     self.total_requested_bytes += bend - start
#     480     self.miss_count += 1
# --> 481     self.cache = self.fetcher(start, bend)
#     482     self.start = start
#     483 else:
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/miniconda3/envs/earth-analytics-python/lib/python3.11/site-packages/fsspec/asyn.py:101, in sync(loop, func, timeout, *args, **kwargs)
#      98 return_result = result[0]
#      99 if isinstance(return_result, asyncio.TimeoutError):
#     100     # suppress asyncio.TimeoutError, raise FSTimeoutError
# --> 101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
#     103     raise return_result
#
# FSTimeoutError:

# %%
def process_cloud_mask(cloud_uri, bounds_gdf, bits_to_mask):
    """
    Load an 8-bit Fmask file and process to a boolean mask

    Parameters
    ----------
    uri: file-like or path-like
      Fmask file accessor downloaded or obtained from earthaccess
    bounds_gdf: gpd.GeoDataFrame
      Area of interest to crop to
    bits_to_mask: list of int
      The indices of the bits to mask if set

    Returns
    -------
    cloud_mask: np.array
      Cloud mask
   
     """
    #open fmask file
    fmask_da = process_image (cloud_uri, bounds_gdf)

    #unlock the cloud mask bits
    cloud_bits = (
    np.unpackbits(
        (
            # Get the cloud mask as an array...
            fmask_da.values
            # ... of 8-bit integers
            .astype('uint8')
            # With an extra axis to unpack the bits into
            [:, :, np.newaxis]
        ), 
        # List the least significat bit first to match the user guide
        bitorder='little',
        # Expand the array in a new dimension
        axis=-1)
    )

    cloud_mask = np.sum(
        # Select bits
        cloud_bits[:,:,bits_to_mask], 
        # Sum along the bit axis
        axis=-1
    # Check if any of bits are true
    ) == 0
    return cloud_mask

blue_da = process_image(denver_files[4], denver_redlining_gdf)
denver_cloud_mask = process_cloud_mask(
    denver_files[1],
   denver_redlining_gdf,
   [1, 2, 3, 5])
blue_da.where(denver_cloud_mask).plot()
# Out:
# /var/folders/j7/815c6qns6g39vvr0gw7cftfm0000gn/T/ipykernel_56624/2492181694.py:30: RuntimeWarning: invalid value encountered in cast
#   .astype('uint8')

# %% [markdown]
# Our next new tool to help you write DRY and correct code is the regular
# expression. Regular expressions are a little like the patterns we use
# with `glob` that contain wildcard characters (`*`) – but, they are
# **much** more powerful. With regular expressions, we can extract
# different segments from a string (file name, in this case) based on
# landmarks – even if those segments are not always the same length!
#
# First – run another `earthaccess` search, this time removing the
# `count=1` argument, or setting it to `count=-1`. This will include all
# the results.

# %%
# Search earthaccess
earthaccess.login(strategy="interactive", persist=True)

# Search for HLS data
denver_results = earthaccess.search_data(
    short_name="HLSL30",
    bounding_box=tuple(denver_redlining_gdf.total_bounds),
    temporal=("2024-07-12", "2024-07-13"),
)
denver_results

# Open earthaccess results
denver_files = earthaccess.open(denver_results)
# Out:
# QUEUEING TASKS | :   0%|          | 0/60 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/60 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/60 [00:00<?, ?it/s]

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Get metadata with **regular expressions**</div></div><div class="callout-body-container callout-body"><p>Using the code below as a starting point, extract metadata from file
# names and put them into a <code>DataFrame</code>. This strategy will
# help you later on because you will be able to group rasters by their
# metadata values, such as tile ID, band ID, and/or date.</p>
# <ol type="1">
# <li>Build your regular expression. ChatGPT is a great tool to get
# started with your regular expression. You can also check out <a
# href="https://regex101.com/">https://regex101.com/</a> to test your
# regular expressions, making sure to select the <code>Python</code>
# regular expression engine.</li>
# <li>Replace file_name with a <strong>string</strong> version of the URI.
# You can access it from the object you got from <code>earthaccess</code>
# through the <code>.full_name</code> attribute.</li>
# <li>Add the URIs from <code>earthaccess</code> to the
# <code>DataFrame</code> you created as a new column.</li>
# </ol></div></div>

# %%
denver_files[4].full_name
# Out:
# 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TEE.2024195T174255.v2.0/HLS.L30.T13TEE.2024195T174255.v2.0.SAA.tif'

# %%
# Compile a regular expression to search for metadata
uri_re = re.compile(
    r"HLS\.L30\.(?P<tile_id>T[0-9A-Z]+)\.(?P<date>\d+)T\d+\.v2\.0\.(?P<band_id>.+)\.tif"
)
#uri_re.search(denver_files[4].full_name).groupdict()
# Find all the metadata in the file name
uri_groups = [
   uri_re.search(denver_file.full_name).groupdict()
   for denver_file in denver_files]

# Create a DataFrame with the metadata
raster_df = pd.DataFrame(uri_groups)

# Add the File-like URI to the DataFrame
raster_df['file'] = denver_files

# Check the results
raster_df
# Out:
#    tile_id     date band_id                                               file
# 0   T13TEE  2024195     B03  <File-like object HTTPFileSystem, https://data...
# 1   T13TEE  2024195   Fmask  <File-like object HTTPFileSystem, https://data...
# 2   T13TEE  2024195     B07  <File-like object HTTPFileSystem, https://data...
# 3   T13TEE  2024195     VAA  <File-like object HTTPFileSystem, https://data...
# 4   T13TEE  2024195     SAA  <File-like object HTTPFileSystem, https://data...
# 5   T13TEE  2024195     B01  <File-like object HTTPFileSystem, https://data...
# 6   T13TEE  2024195     B09  <File-like object HTTPFileSystem, https://data...
# 7   T13TEE  2024195     B06  <File-like object HTTPFileSystem, https://data...
# 8   T13TEE  2024195     B10  <File-like object HTTPFileSystem, https://data...
# 9   T13TEE  2024195     B02  <File-like object HTTPFileSystem, https://data...
# 10  T13TEE  2024195     SZA  <File-like object HTTPFileSystem, https://data...
# 11  T13TEE  2024195     B11  <File-like object HTTPFileSystem, https://data...
# 12  T13TEE  2024195     B04  <File-like object HTTPFileSystem, https://data...
# 13  T13TEE  2024195     VZA  <File-like object HTTPFileSystem, https://data...
# 14  T13TEE  2024195     B05  <File-like object HTTPFileSystem, https://data...
# 15  T13SDD  2024195     SAA  <File-like object HTTPFileSystem, https://data...
# 16  T13SDD  2024195     B04  <File-like object HTTPFileSystem, https://data...
# 17  T13SDD  2024195   Fmask  <File-like object HTTPFileSystem, https://data...
# 18  T13SDD  2024195     B07  <File-like object HTTPFileSystem, https://data...
# 19  T13SDD  2024195     B01  <File-like object HTTPFileSystem, https://data...
# 20  T13SDD  2024195     B02  <File-like object HTTPFileSystem, https://data...
# 21  T13SDD  2024195     B10  <File-like object HTTPFileSystem, https://data...
# 22  T13SDD  2024195     VAA  <File-like object HTTPFileSystem, https://data...
# 23  T13SDD  2024195     B09  <File-like object HTTPFileSystem, https://data...
# 24  T13SDD  2024195     B11  <File-like object HTTPFileSystem, https://data...
# 25  T13SDD  2024195     SZA  <File-like object HTTPFileSystem, https://data...
# 26  T13SDD  2024195     VZA  <File-like object HTTPFileSystem, https://data...
# 27  T13SDD  2024195     B05  <File-like object HTTPFileSystem, https://data...
# 28  T13SDD  2024195     B06  <File-like object HTTPFileSystem, https://data...
# 29  T13SDD  2024195     B03  <File-like object HTTPFileSystem, https://data...
# 30  T13SED  2024195     B10  <File-like object HTTPFileSystem, https://data...
# 31  T13SED  2024195     B01  <File-like object HTTPFileSystem, https://data...
# 32  T13SED  2024195     SAA  <File-like object HTTPFileSystem, https://data...
# 33  T13SED  2024195     SZA  <File-like object HTTPFileSystem, https://data...
# 34  T13SED  2024195     VAA  <File-like object HTTPFileSystem, https://data...
# 35  T13SED  2024195     B05  <File-like object HTTPFileSystem, https://data...
# 36  T13SED  2024195     B06  <File-like object HTTPFileSystem, https://data...
# 37  T13SED  2024195     B11  <File-like object HTTPFileSystem, https://data...
# 38  T13SED  2024195     B04  <File-like object HTTPFileSystem, https://data...
# 39  T13SED  2024195     B07  <File-like object HTTPFileSystem, https://data...
# 40  T13SED  2024195     B09  <File-like object HTTPFileSystem, https://data...
# 41  T13SED  2024195     B02  <File-like object HTTPFileSystem, https://data...
# 42  T13SED  2024195     VZA  <File-like object HTTPFileSystem, https://data...
# 43  T13SED  2024195     B03  <File-like object HTTPFileSystem, https://data...
# 44  T13SED  2024195   Fmask  <File-like object HTTPFileSystem, https://data...
# 45  T13TDE  2024195     SAA  <File-like object HTTPFileSystem, https://data...
# 46  T13TDE  2024195     B02  <File-like object HTTPFileSystem, https://data...
# 47  T13TDE  2024195     B09  <File-like object HTTPFileSystem, https://data...
# 48  T13TDE  2024195   Fmask  <File-like object HTTPFileSystem, https://data...
# 49  T13TDE  2024195     B03  <File-like object HTTPFileSystem, https://data...
# 50  T13TDE  2024195     VAA  <File-like object HTTPFileSystem, https://data...
# 51  T13TDE  2024195     B01  <File-like object HTTPFileSystem, https://data...
# 52  T13TDE  2024195     B07  <File-like object HTTPFileSystem, https://data...
# 53  T13TDE  2024195     B06  <File-like object HTTPFileSystem, https://data...
# 54  T13TDE  2024195     VZA  <File-like object HTTPFileSystem, https://data...
# 55  T13TDE  2024195     SZA  <File-like object HTTPFileSystem, https://data...
# 56  T13TDE  2024195     B04  <File-like object HTTPFileSystem, https://data...
# 57  T13TDE  2024195     B10  <File-like object HTTPFileSystem, https://data...
# 58  T13TDE  2024195     B11  <File-like object HTTPFileSystem, https://data...
# 59  T13TDE  2024195     B05  <File-like object HTTPFileSystem, https://data...

# %% [markdown]
# Now you are ready to run your code repeatedly on each raster you want to
# load. To do this, we’ll use a structure called a `for` loop, which runs
# the same code repeatedly with different variable values. The values that
# change are special variables called **looping variables**.
#
# To set up a `for` loop, you can use the following process:
#
# 1.  Copy the code you’re using into the `for` loop shell, making sure to
#     indent it so Python knows it is part of the loop.
# 2.  Identify any variables that are **too specific**. For example, if I
#     called a `DataArray` `green_da`, but the loop will be processing
#     data from other bands…I might change the name to `da` whereever it
#     appears.
# 3.  Identify the **looping variable(s)** and make sure they match your
#     code.
# 4.  Establish an **accumulator** – a data structure to store the result.
#     Add what you want to keep from each iteration of the loop to it.
# 5.  Write some code to test your loop, such as by printing out an
#     intermediate value in the loop, or eventually plotting the final
#     results. We recommend going line by line when you’re just getting
#     started. This usually involves commenting code later on, and
#     modifying the accumulator and testing as you go. You can also use
#     the `break` keywork to stop the loop after a single iteration for
#     testing.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Process data</div></div><div class="callout-body-container callout-body"><p>Process all your bands. We’ve provided the structure of the
# <code>for</code> loop – you will need to call your functions and work
# out how to pass them the arguments they need.</p>
# <p>Something that is tricky about looping through
# <code>DataFrame</code>s is that they tend to wrap values in external
# structures like <code>Series</code> (which are the data type of columns
# in a <code>DataFrame</code>). The print out of a <code>Series</code>
# containing one value and the print out of that value are not identical,
# but the are <strong>very similar</strong>. To get a
# <strong>value</strong> out from inside a <code>Series</code>, you can
# add the following code: <code>.values[0]</code>. This will first remove
# the <code>Series</code> wrapper, leaving an array, and the get the first
# value in the array.</p></div></div>

# %%
# Labels for each band to process
bands = {
    'B02': 'red',
    'B03': 'green',
    'B04': 'blue',
    'B05': 'nir'
}
# Initialize structure for saving images
denver_das = {band_name: [] for band_name in bands.values()}
for tile_id, tile_df in raster_df.groupby('tile_id'):
    #Load the cloud mask
    fmask_file = tile_df[tile_df.band_id=='Fmask'].file.values[0]
    cloud_mask = process_cloud_mask(
        fmask_file, 
        denver_redlining_gdf,
         [1, 2, 3, 5])

    for band_id, row in tile_df.groupby('band_id'):
        if band_id in bands:
            band_name = bands[band_id]
            print (band_id, band_name)
            # Process band
            band_da = process_image(
                row.file.values[0],
                denver_redlining_gdf)

             # Mask band
            band_masked_da = band_da.where(cloud_mask)
            display(band_da)



            # Store the resulting DataArray for later
            denver_das[band_name].append(band_masked_da)
# Out:
# /var/folders/j7/815c6qns6g39vvr0gw7cftfm0000gn/T/ipykernel_56624/2492181694.py:30: RuntimeWarning: invalid value encountered in cast
#   .astype('uint8')
# B02 red
# <xarray.DataArray (y: 447, x: 504)> Size: 901kB
# [225288 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B03 green
# <xarray.DataArray (y: 447, x: 504)> Size: 901kB
# [225288 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B04 blue
# <xarray.DataArray (y: 447, x: 504)> Size: 901kB
# [225288 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B05 nir
# <xarray.DataArray (y: 447, x: 504)> Size: 901kB
# [225288 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# /var/folders/j7/815c6qns6g39vvr0gw7cftfm0000gn/T/ipykernel_56624/2492181694.py:30: RuntimeWarning: invalid value encountered in cast
#   .astype('uint8')
# B02 red
# <xarray.DataArray (y: 447, x: 355)> Size: 635kB
# [158685 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       499980
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B03 green
# <xarray.DataArray (y: 447, x: 355)> Size: 635kB
# [158685 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       499980
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B04 blue
# <xarray.DataArray (y: 447, x: 355)> Size: 635kB
# [158685 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       499980
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B05 nir
# <xarray.DataArray (y: 447, x: 355)> Size: 635kB
# [158685 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       499980
#     ULY:                       4400040
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B02 red
# <xarray.DataArray (y: 480, x: 504)> Size: 968kB
# [241920 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B03 green
# <xarray.DataArray (y: 480, x: 504)> Size: 968kB
# [241920 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B04 blue
# <xarray.DataArray (y: 480, x: 504)> Size: 968kB
# [241920 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B05 nir
# <xarray.DataArray (y: 480, x: 504)> Size: 968kB
# [241920 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc; Lasrc
#     arop_ave_xshift(meters):   0, 0
#     arop_ave_yshift(meters):   0, 0
#     arop_ncp:                  0, 0
#     arop_rmse(meters):         0, 0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#     ULX:                       399960
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# /var/folders/j7/815c6qns6g39vvr0gw7cftfm0000gn/T/ipykernel_56624/2492181694.py:30: RuntimeWarning: invalid value encountered in cast
#   .astype('uint8')
# B02 red
# <xarray.DataArray (y: 480, x: 355)> Size: 682kB
# [170400 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc
#     arop_ave_xshift(meters):   0
#     arop_ave_yshift(meters):   0
#     arop_ncp:                  0
#     arop_rmse(meters):         0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED
#     ULX:                       499980
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B03 green
# <xarray.DataArray (y: 480, x: 355)> Size: 682kB
# [170400 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc
#     arop_ave_xshift(meters):   0
#     arop_ave_yshift(meters):   0
#     arop_ncp:                  0
#     arop_rmse(meters):         0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED
#     ULX:                       499980
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B04 blue
# <xarray.DataArray (y: 480, x: 355)> Size: 682kB
# [170400 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc
#     arop_ave_xshift(meters):   0
#     arop_ave_yshift(meters):   0
#     arop_ncp:                  0
#     arop_rmse(meters):         0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED
#     ULX:                       499980
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area
# B05 nir
# <xarray.DataArray (y: 480, x: 355)> Size: 682kB
# [170400 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#   * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#     spatial_ref  int64 8B 0
# Attributes: (12/33)
#     ACCODE:                    Lasrc
#     arop_ave_xshift(meters):   0
#     arop_ave_yshift(meters):   0
#     arop_ncp:                  0
#     arop_rmse(meters):         0
#     arop_s2_refimg:            NONE
#     ...                        ...
#     TIRS_SSM_MODEL:            PRELIMINARY
#     TIRS_SSM_POSITION_STATUS:  ESTIMATED
#     ULX:                       499980
#     ULY:                       4500000
#     USGS_SOFTWARE:             LPGS_16.4.0
#     AREA_OR_POINT:             Area

# %%
denver_das
# Out:
# {'red': [<xarray.DataArray (y: 447, x: 504)> Size: 901kB
#   array([[0.0588, 0.0624, 0.0564, ..., 0.08  , 0.0755, 0.0615],
#          [0.0616, 0.0582, 0.0546, ..., 0.0906, 0.0807, 0.0704],
#          [0.064 , 0.0565, 0.0614, ..., 0.0896, 0.0788, 0.0742],
#          ...,
#          [   nan,    nan,    nan, ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan, ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan, ...,    nan,    nan,    nan]],
#         dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 447, x: 355)> Size: 635kB
#   array([[0.12619999, 0.0865    , 0.1529    , ..., 0.11009999, 0.0702    ,
#           0.0849    ],
#          [0.1507    , 0.1996    , 0.2126    , ..., 0.1215    , 0.0857    ,
#           0.0584    ],
#          [0.21869999, 0.26749998, 0.18169999, ..., 0.12789999, 0.0805    ,
#           0.0158    ],
#          ...,
#          [0.0597    , 0.0787    , 0.0585    , ...,        nan,        nan,
#                  nan],
#          [0.0549    , 0.0628    , 0.0626    , ...,        nan,        nan,
#                  nan],
#          [0.0642    , 0.0696    , 0.0792    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       499980
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 504)> Size: 968kB
#   array([[0.0909    , 0.09559999, 0.0797    , ..., 0.08329999, 0.0847    ,
#           0.08899999],
#          [0.0953    , 0.0977    , 0.0657    , ..., 0.0739    , 0.08      ,
#           0.0761    ],
#          [0.10219999, 0.0913    , 0.0548    , ..., 0.0623    , 0.0631    ,
#           0.0696    ],
#          ...,
#          [0.0665    , 0.0645    , 0.0824    , ..., 0.0623    , 0.0679    ,
#           0.0582    ],
#          [0.039     , 0.0489    , 0.075     , ..., 0.087     , 0.0721    ,
#           0.0464    ],
#          [0.0487    , 0.0484    , 0.0587    , ..., 0.0808    , 0.0818    ,
#           0.0582    ]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 355)> Size: 682kB
#   array([[0.1162    , 0.1146    , 0.1012    , ..., 0.0914    , 0.0874    ,
#           0.0713    ],
#          [0.1068    , 0.10879999, 0.1012    , ..., 0.0975    , 0.0847    ,
#           0.0695    ],
#          [0.101     , 0.1099    , 0.1023    , ..., 0.11009999, 0.0969    ,
#           0.0787    ],
#          ...,
#          [0.0995    , 0.0947    , 0.1072    , ...,        nan,        nan,
#                  nan],
#          [0.0925    , 0.0905    , 0.106     , ...,        nan,        nan,
#                  nan],
#          [0.0878    , 0.0834    , 0.09119999, ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc
#       arop_ave_xshift(meters):   0
#       arop_ave_yshift(meters):   0
#       arop_ncp:                  0
#       arop_rmse(meters):         0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED
#       ULX:                       499980
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area],
#  'green': [<xarray.DataArray (y: 447, x: 504)> Size: 901kB
#   array([[0.0835    , 0.0902    , 0.0867    , ..., 0.1064    , 0.1014    ,
#           0.0905    ],
#          [0.0857    , 0.0804    , 0.0795    , ..., 0.12419999, 0.1068    ,
#           0.0981    ],
#          [0.08899999, 0.078     , 0.0824    , ..., 0.1237    , 0.1089    ,
#           0.10529999],
#          ...,
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 447, x: 355)> Size: 635kB
#   array([[0.16759999, 0.1156    , 0.2065    , ..., 0.156     , 0.1179    ,
#           0.1217    ],
#          [0.20629999, 0.2577    , 0.2771    , ..., 0.1604    , 0.1213    ,
#           0.0975    ],
#          [0.254     , 0.3159    , 0.22      , ..., 0.1593    , 0.11059999,
#           0.0321    ],
#          ...,
#          [0.08679999, 0.1139    , 0.0813    , ...,        nan,        nan,
#                  nan],
#          [0.0828    , 0.0936    , 0.0888    , ...,        nan,        nan,
#                  nan],
#          [0.09869999, 0.09959999, 0.1061    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       499980
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 504)> Size: 968kB
#   array([[0.1146    , 0.1236    , 0.1059    , ..., 0.1161    , 0.1215    ,
#           0.1277    ],
#          [0.1219    , 0.1294    , 0.0882    , ..., 0.1099    , 0.1186    ,
#           0.1147    ],
#          [0.1331    , 0.1192    , 0.0752    , ..., 0.09959999, 0.0977    ,
#           0.1054    ],
#          ...,
#          [0.0919    , 0.0879    , 0.1103    , ..., 0.0907    , 0.0954    ,
#           0.0834    ],
#          [0.0742    , 0.0725    , 0.0968    , ..., 0.1187    , 0.1007    ,
#           0.0729    ],
#          [0.0765    , 0.06879999, 0.0766    , ..., 0.1105    , 0.1143    ,
#           0.0849    ]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 355)> Size: 682kB
#   array([[0.1488    , 0.1463    , 0.12969999, ..., 0.13059999, 0.12799999,
#           0.1199    ],
#          [0.138     , 0.1452    , 0.1312    , ..., 0.1374    , 0.1294    ,
#           0.12      ],
#          [0.1514    , 0.1461    , 0.1293    , ..., 0.15439999, 0.1449    ,
#           0.1303    ],
#          ...,
#          [0.1364    , 0.1304    , 0.1497    , ...,        nan,        nan,
#                  nan],
#          [0.1287    , 0.1243    , 0.1471    , ...,        nan,        nan,
#                  nan],
#          [0.1161    , 0.1061    , 0.1164    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc
#       arop_ave_xshift(meters):   0
#       arop_ave_yshift(meters):   0
#       arop_ncp:                  0
#       arop_rmse(meters):         0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED
#       ULX:                       499980
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area],
#  'blue': [<xarray.DataArray (y: 447, x: 504)> Size: 901kB
#   array([[0.083     , 0.0925    , 0.0896    , ..., 0.1173    , 0.1104    ,
#           0.0927    ],
#          [0.0903    , 0.0869    , 0.0821    , ..., 0.1352    , 0.116     ,
#           0.10399999],
#          [0.0977    , 0.0881    , 0.0893    , ..., 0.1375    , 0.1204    ,
#           0.1131    ],
#          ...,
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 447, x: 355)> Size: 635kB
#   array([[0.1927    , 0.13059999, 0.2348    , ..., 0.1633    , 0.1236    ,
#           0.132     ],
#          [0.24749999, 0.2995    , 0.3094    , ..., 0.16929999, 0.1284    ,
#           0.1012    ],
#          [0.282     , 0.3651    , 0.24859999, ..., 0.1753    , 0.1196    ,
#           0.0326    ],
#          ...,
#          [0.0869    , 0.1214    , 0.0845    , ...,        nan,        nan,
#                  nan],
#          [0.0825    , 0.0967    , 0.0917    , ...,        nan,        nan,
#                  nan],
#          [0.10839999, 0.1074    , 0.1147    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       499980
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 504)> Size: 968kB
#   array([[0.1303    , 0.1441    , 0.1168    , ..., 0.1389    , 0.1488    ,
#           0.1537    ],
#          [0.1463    , 0.1566    , 0.0911    , ..., 0.1228    , 0.1389    ,
#           0.1352    ],
#          [0.1617    , 0.14389999, 0.0782    , ..., 0.1055    , 0.1039    ,
#           0.116     ],
#          ...,
#          [0.1019    , 0.09119999, 0.1268    , ..., 0.0958    , 0.0995    ,
#           0.0832    ],
#          [0.0758    , 0.076     , 0.10619999, ..., 0.1321    , 0.1055    ,
#           0.07319999],
#          [0.0772    , 0.0702    , 0.0728    , ..., 0.1199    , 0.1256    ,
#           0.0955    ]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 355)> Size: 682kB
#   array([[0.1715    , 0.1688    , 0.148     , ..., 0.1813    , 0.17999999,
#           0.1758    ],
#          [0.1585    , 0.169     , 0.152     , ..., 0.1815    , 0.1801    ,
#           0.1742    ],
#          [0.1838    , 0.1793    , 0.14739999, ..., 0.1858    , 0.184     ,
#           0.17109999],
#          ...,
#          [0.17199999, 0.1601    , 0.1762    , ...,        nan,        nan,
#                  nan],
#          [0.1704    , 0.1512    , 0.1679    , ...,        nan,        nan,
#                  nan],
#          [0.1461    , 0.1237    , 0.1278    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc
#       arop_ave_xshift(meters):   0
#       arop_ave_yshift(meters):   0
#       arop_ncp:                  0
#       arop_rmse(meters):         0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED
#       ULX:                       499980
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area],
#  'nir': [<xarray.DataArray (y: 447, x: 504)> Size: 901kB
#   array([[0.2566    , 0.28329998, 0.2679    , ..., 0.2049    , 0.1863    ,
#           0.23089999],
#          [0.2489    , 0.22459999, 0.2382    , ..., 0.2338    , 0.2049    ,
#           0.2297    ],
#          [0.20349999, 0.1802    , 0.20109999, ..., 0.2348    , 0.2348    ,
#           0.23609999],
#          ...,
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan],
#          [       nan,        nan,        nan, ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 447, x: 355)> Size: 635kB
#   array([[0.2454    , 0.1898    , 0.27989998, ..., 0.17019999, 0.1661    ,
#           0.1911    ],
#          [0.2908    , 0.3419    , 0.3356    , ..., 0.1739    , 0.1601    ,
#           0.1486    ],
#          [0.3385    , 0.4172    , 0.2764    , ..., 0.1845    , 0.16149999,
#           0.1104    ],
#          ...,
#          [0.3294    , 0.2686    , 0.2461    , ...,        nan,        nan,
#                  nan],
#          [0.308     , 0.2844    , 0.252     , ...,        nan,        nan,
#                  nan],
#          [0.2733    , 0.2649    , 0.2698    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.4e+06 4.4e+06 4.4e+06 ... 4.387e+06 4.387e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       499980
#       ULY:                       4400040
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 504)> Size: 968kB
#   array([[0.16229999, 0.1989    , 0.2096    , ..., 0.2571    , 0.26229998,
#           0.2701    ],
#          [0.20019999, 0.2438    , 0.22489999, ..., 0.2437    , 0.2525    ,
#           0.2511    ],
#          [0.2365    , 0.2496    , 0.2244    , ..., 0.221     , 0.1867    ,
#           0.2173    ],
#          ...,
#          [0.251     , 0.2566    , 0.22929999, ..., 0.2838    , 0.2661    ,
#           0.26659998],
#          [0.29999998, 0.2689    , 0.24409999, ..., 0.2625    , 0.2773    ,
#           0.3011    ],
#          [0.29549998, 0.2911    , 0.3181    , ..., 0.2631    , 0.29189998,
#           0.3046    ]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 4kB 4.947e+05 4.947e+05 ... 5.097e+05 5.097e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc; Lasrc
#       arop_ave_xshift(meters):   0, 0
#       arop_ave_yshift(meters):   0, 0
#       arop_ncp:                  0, 0
#       arop_rmse(meters):         0, 0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY; PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED; ESTIMATED
#       ULX:                       399960
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area,
#   <xarray.DataArray (y: 480, x: 355)> Size: 682kB
#   array([[0.20699999, 0.20289999, 0.1726    , ..., 0.32439998, 0.32099998,
#           0.3206    ],
#          [0.1916    , 0.206     , 0.17979999, ..., 0.2952    , 0.3132    ,
#           0.3162    ],
#          [0.23249999, 0.2235    , 0.1743    , ..., 0.2638    , 0.2805    ,
#           0.269     ],
#          ...,
#          [0.2905    , 0.2541    , 0.23539999, ...,        nan,        nan,
#                  nan],
#          [0.2793    , 0.2408    , 0.2276    , ...,        nan,        nan,
#                  nan],
#          [0.2624    , 0.2084    , 0.1661    , ...,        nan,        nan,
#                  nan]], dtype=float32)
#   Coordinates:
#       band         int64 8B 1
#     * x            (x) float64 3kB 5e+05 5e+05 5.001e+05 ... 5.106e+05 5.106e+05
#     * y            (y) float64 4kB 4.405e+06 4.405e+06 ... 4.39e+06 4.39e+06
#       spatial_ref  int64 8B 0
#   Attributes: (12/33)
#       ACCODE:                    Lasrc
#       arop_ave_xshift(meters):   0
#       arop_ave_yshift(meters):   0
#       arop_ncp:                  0
#       arop_rmse(meters):         0
#       arop_s2_refimg:            NONE
#       ...                        ...
#       TIRS_SSM_MODEL:            PRELIMINARY
#       TIRS_SSM_POSITION_STATUS:  ESTIMATED
#       ULX:                       499980
#       ULY:                       4500000
#       USGS_SOFTWARE:             LPGS_16.4.0
#       AREA_OR_POINT:             Area]}

# %%
# Merge all tiles
denver_merged_das = {
    band_name: merge_arrays(das) 
    for band_name, das 
    in denver_das.items()}

denver_merged_das['green'].plot(cmap='Greens', robust=True)

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It: Check your data</div></div><div class="callout-body-container callout-body"><p>Make a plot of one of your merged bands with the denver boundary
# superimposed. You should now have data for the whole city!</p></div></div>

# %%
# Plot a merged raster band
denver_merged_das['green'].plot(cmap='Greens', robust=True)
